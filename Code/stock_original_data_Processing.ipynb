# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import dask.dataframe as dd
import dask.array as da

# %%
data_path = '/home/bld/bld_data/pengliu/Stock Data/CRSP_daily_price_19600101_20211221.dta'
df = pd.read_stata(data_path)

# %%
df.head()
# Out:
#     PERMNO       date   NAMEENDT  SHRCD  EXCHCD   SICCD    NCUSIP TICKER  \
# 0  10000.0 1986-01-06        NaT    NaN     NaN     NaN
# 1  10000.0 1986-01-07 1986-12-03   10.0     3.0  3990.0  68391610  OMFGA
# 2  10000.0 1986-01-08        NaT   10.0     3.0  3990.0  68391610  OMFGA
# 3  10000.0 1986-01-09        NaT   10.0     3.0  3990.0  68391610  OMFGA
# 4  10000.0 1986-01-10        NaT   10.0     3.0  3990.0  68391610  OMFGA
#
#                       COMNAM SHRCLS  ... SHRFLG   SHRENDDT NWPERM     PRC  \
# 0                                    ...    NaN        NaT    NaN     NaN
# 1  OPTIMUM MANUFACTURING INC      A  ...    2.0 1986-01-30    NaN -2.5625
# 2  OPTIMUM MANUFACTURING INC      A  ...    NaN        NaT    NaN -2.5000
# 3  OPTIMUM MANUFACTURING INC      A  ...    NaN        NaT    NaN -2.5000
# 4  OPTIMUM MANUFACTURING INC      A  ...    2.0        NaT    NaN -2.5000
#
#        VOL      RET  SHROUT OPENPRC  NUMTRD     RETX
# 0      NaN      NaN     NaN     NaN     NaN      NaN
# 1   1000.0      NaN  3680.0     NaN     NaN      NaN
# 2  12800.0 -0.02439  3680.0     NaN     NaN -0.02439
# 3   1400.0  0.00000  3680.0     NaN     NaN  0.00000
# 4   8500.0  0.00000  3680.0     NaN     NaN  0.00000
#
# [5 rows x 29 columns]

# %%
df.tail()
# Out:
#            PERMNO       date NAMEENDT  SHRCD  EXCHCD   SICCD    NCUSIP TICKER  \
# 94759046  93436.0 2022-12-23      NaT   11.0     3.0  9999.0  88160R10   TSLA
# 94759047  93436.0 2022-12-27      NaT   11.0     3.0  9999.0  88160R10   TSLA
# 94759048  93436.0 2022-12-28      NaT   11.0     3.0  9999.0  88160R10   TSLA
# 94759049  93436.0 2022-12-29      NaT   11.0     3.0  9999.0  88160R10   TSLA
# 94759050  93436.0 2022-12-30      NaT   11.0     3.0  9999.0  88160R10   TSLA
#
#              COMNAM SHRCLS  ... SHRFLG SHRENDDT NWPERM         PRC  \
# 94759046  TESLA INC         ...    NaN      NaT    NaN  123.150002
# 94759047  TESLA INC         ...    NaN      NaT    NaN  109.099998
# 94759048  TESLA INC         ...    NaN      NaT    NaN  112.709999
# 94759049  TESLA INC         ...    NaN      NaT    NaN  121.820000
# 94759050  TESLA INC         ...    0.0      NaT    0.0  123.180000
#
#                   VOL       RET     SHROUT     OPENPRC     NUMTRD      RETX
# 94759046  166917212.0 -0.017551  3157752.0  126.370003  1561465.0 -0.017551
# 94759047  208446557.0 -0.114089  3157752.0  117.495003  2064134.0 -0.114089
# 94759048  220818648.0  0.033089  3157752.0  110.349998  2050924.0  0.033089
# 94759049  221592714.0  0.080827  3157752.0  120.385002  1905930.0  0.080827
# 94759050  157632606.0  0.011164  3157752.0  119.949997  1506631.0  0.011164
#
# [5 rows x 29 columns]

# %%
df.shape
# Out:
# (94759051, 29)

# %%
df.columns
# Out:
# Index(['PERMNO', 'date', 'NAMEENDT', 'SHRCD', 'EXCHCD', 'SICCD', 'NCUSIP',
#        'TICKER', 'COMNAM', 'SHRCLS', 'TSYMBOL', 'NAICS', 'PRIMEXCH', 'TRDSTAT',
#        'SECSTAT', 'PERMCO', 'HEXCD', 'CUSIP', 'DLSTCD', 'SHRFLG', 'SHRENDDT',
#        'NWPERM', 'PRC', 'VOL', 'RET', 'SHROUT', 'OPENPRC', 'NUMTRD', 'RETX'],
#       dtype='object')

# %% [markdown]
# 以下是CRSP股价数据中每个列名的含义解释：
#
# 1. **PERMNO**：永久编号，唯一标识证券的数字代码。
# 2. **date**：交易日期。
# 3. **NAMEENDT**：公司名称结束日期。
# 4. **SHRCD**：股票类别代码，指示股票的类别（如普通股、优先股等）。
# 5. **EXCHCD**：交易所代码，表示证券在哪个交易所交易。
# 6. **SICCD**：标准行业分类代码（Standard Industrial Classification Code），用于分类公司所属行业。
# 7. **NCUSIP**：新的CUSIP代码，用于标识证券的唯一代码。
# 8. **TICKER**：股票代码。
# 9. **COMNAM**：公司名称。
# 10. **SHRCLS**：股票类别，如A股、B股等。
# 11. **TSYMBOL**：交易所符号。
# 12. **NAICS**：北美行业分类系统代码（North American Industry Classification System），用于分类公司所属行业。
# 13. **PRIMEXCH**：主要交易所代码，表示证券主要在哪个交易所交易。
# 14. **TRDSTAT**：交易状态，表示股票的当前交易状态（如正常交易、暂停交易等）。
# 15. **SECSTAT**：证券状态，表示证券的当前状态（如有效、无效等）。
# 16. **PERMCO**：永久公司编号，唯一标识公司的数字代码。
# 17. **HEXCD**：历史交易所代码。
# 18. **CUSIP**：CUSIP代码，用于标识证券的唯一代码。
# 19. **DLSTCD**：摘牌代码，表示股票被摘牌的原因。
# 20. **SHRFLG**：股票标识，指示股票是否有效。
# 21. **SHRENDDT**：股票结束日期。
# 22. **NWPERM**：新的永久编号。
# 23. **PRC**：股价，通常为收盘价。
# 24. **VOL**：交易量，以股票数量表示。
# 25. **RET**：当日的股票回报率。
# 26. **SHROUT**：已发行股票数量。
# 27. **OPENPRC**：开盘价。
# 28. **NUMTRD**：当日交易笔数。
# 29. **RETX**：不包括分红的回报率。

# %%
df['PERMNO'].nunique()
# Out:
# 36515

# %%
CRSP_stock_data_unique = df['PERMNO'].unique().tolist()
len(CRSP_stock_data_unique)
# Out:
# 36515

# %%
patent_original_data = pd.read_csv('/home/bld/bld_data/pengliu/Graph data/Patent relation/patent_Gen_new/patent_cpc_data.csv')
patent_original_data
# Out:
#          patent_num                                                cpc cpc_1  \
# 0           1570604                                           F23K3/12     F
# 1           1570665                    B26D3/16;Y10T82/16229;B26D3/003     B
# 2           1570677                                F41A19/49;F41A19/15     F
# 3           1570692      E05F5/025;Y10T16/628;Y10T16/6285;E05Y2900/531     E
# 4           1570694                                          B60P3/073     B
# ...             ...                                                ...   ...
# 3160448    11540395  H05K2201/10159;H05K2201/10015;H01L23/5223;H01L...     H
# 3160449    11540408  B23C2226/315;B23C2220/04;B23C2220/16;B23C2220/...     B
# 3160450    11540421                  H05K7/20836;G06F1/206;H05K7/20436     H
# 3160451    11540430  H05K5/0017;H05K7/1427;H01L33/642;H05K7/20963;H...     H
# 3160452    11540432  H05K9/0064;B25J1/00;B65G49/07;H01J37/20;H01J37...     H
#
#         cpc_2  cpc_g1  cpc_g2 cpc_3  cpc_g3  permno  issue_date  filing_date  \
# 0         F23     6.0    99.0  F23K   480.0   15368    19260126   19230604.0
# 1         B26     2.0    30.0  B26D   139.0   11965    19260126   19210627.0
# 2         F41     6.0   105.0  F41A   508.0   10786    19260126   19220726.0
# 3         E05     5.0    86.0  E05F   406.0   10807    19260126   19241117.0
# 4         B60     2.0    42.0  B60P   201.0   14613    19260126   19231217.0
# ...       ...     ...     ...   ...     ...     ...         ...          ...
# 3160448   H05     8.0   126.0  H05K   656.0   59328    20221227   20190624.0
# 3160449   B23     2.0    27.0  B23C   120.0   14593    20221227   20160722.0
# 3160450   H05     8.0   126.0  H05K   656.0   89641    20221227   20200911.0
# 3160451   H05     8.0   126.0  H05K   656.0   90266    20221227   20201225.0
# 3160452   H05     8.0   126.0  H05K   656.0   14702    20221227   20200602.0
#
#          xi_nominal    xi_real  cites  year_issue  month_issue  year_filing  \
# 0          0.156578   0.863388      5        1926            1       1923.0
# 1          0.137627   0.758891      2        1926            1       1921.0
# 2          0.029288   0.161497      0        1926            1       1922.0
# 3          0.508039   2.801388      0        1926            1       1924.0
# 4          0.193691   1.068035      0        1926            1       1923.0
# ...             ...        ...    ...         ...          ...          ...
# 3160448   11.867290   3.902491      0        2022           12       2019.0
# 3160449  168.119060  55.284992      0        2022           12       2016.0
# 3160450   15.761281   5.183007      0        2022           12       2020.0
# 3160451    0.010343   0.003401      0        2022           12       2020.0
# 3160452   52.425938  17.239969      0        2022           12       2020.0
#
#          month_filing
# 0                 6.0
# 1                 6.0
# 2                 7.0
# 3                11.0
# 4                12.0
# ...               ...
# 3160448           6.0
# 3160449           7.0
# 3160450           9.0
# 3160451          12.0
# 3160452           6.0
#
# [3160453 rows x 18 columns]

# %%
# 保存patent_original_data['permno']
patent_original_data_permno = patent_original_data['permno'].unique().tolist()

# %%
len(patent_original_data_permno)
# Out:
# 8547

# %%
df['TICKER'].nunique()
# Out:
# 34007

# %%
df['TICKER'].isnull().sum()
# Out:
# 0

# %%
df['PERMNO'].isnull().sum()
# Out:
# 0

# %%
# 将patent_original_data_permno与df['PERMNO']进行匹配,将无法匹配的数据且在patent_original_data_permno中的数据打印出来
patent_permno = []
num = 0
for i in patent_original_data_permno:
    if i not in CRSP_stock_data_unique:
        patent_permno.append(i)
        num += 1
print(num)
print(patent_permno)
# Out:
# 134
# [11965, 12378, 11682, 15421, 13389, 11957, 12685, 13784, 12263, 13098, 10073, 12597, 14453, 13944, 15552, 15376, 11973, 11869, 10778, 10794, 12618, 14963, 14007, 15683, 18227, 10567, 12589, 11818, 15413, 12415, 15800, 10639, 12925, 16002, 11121, 16037, 14584, 16221, 15245, 15878, 16301, 16491, 15827, 16168, 15288, 10700, 16627, 15261, 10663, 15886, 16918, 25822, 16838, 16045, 19801, 17494, 11324, 16547, 18008, 16993, 18534, 19529, 18120, 18518, 17427, 10452, 17187, 17363, 18219, 19115, 19473, 15739, 17179, 19262, 13282, 18024, 19342, 19369, 18788, 16950, 14680, 15851, 19780, 19094, 19991, 20108, 18614, 17857, 20466, 20642, 17697, 20722, 20634, 20685, 20810, 20650, 20941, 18972, 21362, 21100, 14445, 21565, 21581, 21637, 21688, 21848, 21952, 21725, 21012, 25259, 22656, 22672, 23173, 23368, 22146, 12861, 19705, 23704, 23798, 23747, 23974, 20159, 23966, 23958, 15691, 25275, 25355, 25451, 25240, 25777, 25857, 25435, 26315, 25996]

# %%
patent_permno.sort()
patent_permno
# Out:
# [10073,
#  10452,
#  10567,
#  10639,
#  10663,
#  10700,
#  10778,
#  10794,
#  11121,
#  11324,
#  11682,
#  11818,
#  11869,
#  11957,
#  11965,
#  11973,
#  12263,
#  12378,
#  12415,
#  12589,
#  12597,
#  12618,
#  12685,
#  12861,
#  12925,
#  13098,
#  13282,
#  13389,
#  13784,
#  13944,
#  14007,
#  14445,
#  14453,
#  14584,
#  14680,
#  14963,
#  15245,
#  15261,
#  15288,
#  15376,
#  15413,
#  15421,
#  15552,
#  15683,
#  15691,
#  15739,
#  15800,
#  15827,
#  15851,
#  15878,
#  15886,
#  16002,
#  16037,
#  16045,
#  16168,
#  16221,
#  16301,
#  16491,
#  16547,
#  16627,
#  16838,
#  16918,
#  16950,
#  16993,
#  17179,
#  17187,
#  17363,
#  17427,
#  17494,
#  17697,
#  17857,
#  18008,
#  18024,
#  18120,
#  18219,
#  18227,
#  18518,
#  18534,
#  18614,
#  18788,
#  18972,
#  19094,
#  19115,
#  19262,
#  19342,
#  19369,
#  19473,
#  19529,
#  19705,
#  19780,
#  19801,
#  19991,
#  20108,
#  20159,
#  20466,
#  20634,
#  20642,
#  20650,
#  20685,
#  20722,
#  20810,
#  20941,
#  21012,
#  21100,
#  21362,
#  21565,
#  21581,
#  21637,
#  21688,
#  21725,
#  21848,
#  21952,
#  22146,
#  22656,
#  22672,
#  23173,
#  23368,
#  23704,
#  23747,
#  23798,
#  23958,
#  23966,
#  23974,
#  25240,
#  25259,
#  25275,
#  25355,
#  25435,
#  25451,
#  25777,
#  25822,
#  25857,
#  25996,
#  26315]

# %% [markdown]
# ### patent relation中所涉及的股票中有134只股票的股价数据在CRSP中不存在

# %%
df[df['PERMNO']==15368]
# Out:
#            PERMNO       date NAMEENDT  SHRCD  EXCHCD   SICCD    NCUSIP TICKER  \
# 11963228  15368.0 1960-01-04      NaT   11.0     1.0  3690.0
# 11963229  15368.0 1960-01-05      NaT   11.0     1.0  3690.0
# 11963230  15368.0 1960-01-06      NaT   11.0     1.0  3690.0
# 11963231  15368.0 1960-01-07      NaT   11.0     1.0  3690.0
# 11963232  15368.0 1960-01-08      NaT   11.0     1.0  3690.0
# ...           ...        ...      ...    ...     ...     ...       ...    ...
# 11973380  15368.0 2000-04-28      NaT   11.0     1.0  4833.0  12490K10    CBS
# 11973381  15368.0 2000-05-01      NaT   11.0     1.0  4833.0  12490K10    CBS
# 11973382  15368.0 2000-05-02      NaT   11.0     1.0  4833.0  12490K10    CBS
# 11973383  15368.0 2000-05-03      NaT   11.0     1.0  4833.0  12490K10    CBS
# 11973384  15368.0 2000-05-04      NaT   11.0     1.0  4833.0  12490K10    CBS
#
#                               COMNAM SHRCLS  ... SHRFLG   SHRENDDT   NWPERM  \
# 11963228  WESTINGHOUSE ELECTRIC CORP         ...    NaN        NaT      NaN
# 11963229  WESTINGHOUSE ELECTRIC CORP         ...    NaN        NaT      NaN
# 11963230  WESTINGHOUSE ELECTRIC CORP         ...    NaN        NaT      NaN
# 11963231  WESTINGHOUSE ELECTRIC CORP         ...    NaN        NaT      NaN
# 11963232  WESTINGHOUSE ELECTRIC CORP         ...    NaN        NaT      NaN
# ...                              ...    ...  ...    ...        ...      ...
# 11973380                  C B S CORP         ...    0.0 2000-05-02      NaN
# 11973381                  C B S CORP         ...    NaN        NaT      NaN
# 11973382                  C B S CORP         ...    NaN        NaT      NaN
# 11973383                  C B S CORP         ...    0.0 2000-05-03  76226.0
# 11973384                  C B S CORP         ...    0.0        NaT      NaN
#
#                PRC        VOL       RET    SHROUT   OPENPRC  NUMTRD      RETX
# 11963228  109.5000    12600.0  0.001143   17339.0  111.5000     NaN  0.001143
# 11963229  112.8750    11000.0  0.030822   17339.0  110.5000     NaN  0.030822
# 11963230  111.0000     7500.0 -0.016611   17339.0  113.2500     NaN -0.016611
# 11963231  110.7500     4900.0 -0.002252   17339.0  111.2500     NaN -0.002252
# 11963232  109.0000     5300.0 -0.015801   17339.0  111.2500     NaN -0.015801
# ...            ...        ...       ...       ...       ...     ...       ...
# 11973380   58.8125  1475399.0  0.012917  767184.0   58.0625     NaN  0.012917
# 11973381   60.0000  4940199.0  0.020191  767184.0   58.8125     NaN  0.020191
# 11973382   60.0000  3275799.0  0.000000  767184.0   59.5000     NaN  0.000000
# 11973383   58.7500  2369199.0 -0.020833  767184.0   60.0000     NaN -0.020833
# 11973384       NaN        NaN       NaN       NaN       NaN     NaN       NaN
#
# [10157 rows x 29 columns]

# %%
df[df['PERMNO'] == patent_original_data_permno[0]]['TICKER'].unique()
# Out:
# array(['', 'WX', 'CBS'], dtype=object)

# %%
df[df['PERMNO'] == patent_original_data_permno[1]]['TICKER'].unique()
# Out:
# array([], dtype=object)

# %%
patent_original_data_permno[1]
# Out:
# 11965

# %%
df[df['PERMNO'] == patent_original_data_permno[5]]
# Out:
#           PERMNO       date NAMEENDT  SHRCD  EXCHCD   SICCD    NCUSIP TICKER  \
# 1198123  10401.0 1960-01-04      NaT   11.0     1.0  4810.0
# 1198124  10401.0 1960-01-05      NaT   11.0     1.0  4810.0
# 1198125  10401.0 1960-01-06      NaT   11.0     1.0  4810.0
# 1198126  10401.0 1960-01-07      NaT   11.0     1.0  4810.0
# 1198127  10401.0 1960-01-08      NaT   11.0     1.0  4810.0
# ...          ...        ...      ...    ...     ...     ...       ...    ...
# 1209670  10401.0 2005-11-15      NaT   11.0     1.0  4813.0  00195750      T
# 1209671  10401.0 2005-11-16      NaT   11.0     1.0  4813.0  00195750      T
# 1209672  10401.0 2005-11-17      NaT   11.0     1.0  4813.0  00195750      T
# 1209673  10401.0 2005-11-18      NaT   11.0     1.0  4813.0  00195750      T
# 1209674  10401.0 2005-11-21      NaT   11.0     1.0  4813.0  00195750      T
#
#                                 COMNAM SHRCLS  ... SHRFLG   SHRENDDT   NWPERM  \
# 1198123  AMERICAN TELEPHONE & TELEG CO         ...    NaN        NaT      NaN
# 1198124  AMERICAN TELEPHONE & TELEG CO         ...    NaN        NaT      NaN
# 1198125  AMERICAN TELEPHONE & TELEG CO         ...    NaN        NaT      NaN
# 1198126  AMERICAN TELEPHONE & TELEG CO         ...    NaN        NaT      NaN
# 1198127  AMERICAN TELEPHONE & TELEG CO         ...    NaN        NaT      NaN
# ...                                ...    ...  ...    ...        ...      ...
# 1209670                   A T & T CORP         ...    NaN        NaT      NaN
# 1209671                   A T & T CORP         ...    NaN        NaT      NaN
# 1209672                   A T & T CORP         ...    NaN        NaT      NaN
# 1209673                   A T & T CORP         ...    0.0 2005-11-18  66093.0
# 1209674                   A T & T CORP         ...    0.0        NaT      NaN
#
#                PRC         VOL       RET    SHROUT    OPENPRC  NUMTRD  \
# 1198123  80.375000     47800.0  0.007837  214630.0  80.000000     NaN
# 1198124  81.625000     37200.0  0.015552  214630.0  80.500000     NaN
# 1198125  81.625000     39800.0  0.000000  214630.0  81.750000     NaN
# 1198126  81.250000     25400.0 -0.004594  214630.0  81.500000     NaN
# 1198127  82.125000     32900.0  0.010769  214630.0  81.500000     NaN
# ...            ...         ...       ...       ...        ...     ...
# 1209670  19.870001  19453000.0 -0.002009  803013.0  19.860001     NaN
# 1209671  19.799999   8657100.0 -0.003523  803013.0  19.840000     NaN
# 1209672  20.080000   4192600.0  0.014141  803013.0  19.740000     NaN
# 1209673  20.350000  10597400.0  0.013446  803449.0  20.280001     NaN
# 1209674        NaN         NaN       NaN       NaN        NaN     NaN
#
#              RETX
# 1198123  0.007837
# 1198124  0.015552
# 1198125  0.000000
# 1198126 -0.004594
# 1198127  0.010769
# ...           ...
# 1209670 -0.002009
# 1209671 -0.003523
# 1209672  0.014141
# 1209673  0.013446
# 1209674       NaN
#
# [11552 rows x 29 columns]

# %%
# 将patent_original_data_permno与df中的ticker进行匹配，将PERMON与TICKER以字典的形式保存
patent_permno_ticker = {}
for i in patent_original_data_permno:
    patent_permno_ticker[i] = df[df['PERMNO'] == i]['TICKER'].unique().tolist()
    
patent_permno_ticker
# Out:
# {15368: ['', 'WX', 'CBS'],
#  11965: [],
#  10786: ['', 'BS'],
#  10807: ['', 'BG'],
#  14613: ['', 'SK'],
#  10401: ['', 'T'],
#  14736: ['', 'TX'],
#  11068: ['', 'JI'],
#  14402: ['', 'SIM'],
#  12431: ['', 'IR', 'TT'],
#  14525: ['', 'SY'],
#  15480: ['', 'YAT'],
#  10751: ['', 'BX'],
#  15341: ['', 'WK'],
#  13661: ['', 'OI'],
#  14699: ['', 'SZ'],
#  12378: [],
#  12079: ['', 'GM'],
#  14090: ['', 'RCA'],
#  14605: ['', 'STX'],
#  10102: ['', 'AN'],
#  11164: ['', 'CGG'],
#  15464: ['', 'WTH'],
#  12060: ['', 'GE'],
#  14533: ['', 'SB'],
#  11682: [],
#  14875: ['', 'UNX'],
#  13119: ['', 'MYG'],
#  11754: ['', 'EK'],
#  10292: ['', 'ACJ'],
#  14795: ['', 'TKR'],
#  13063: ['', 'M'],
#  10241: ['', 'AC', 'PA'],
#  12546: ['', 'N'],
#  10671: ['', 'B'],
#  15421: [],
#  10057: ['', 'NCM', 'AMT'],
#  15149: ['', 'VCA'],
#  10735: ['', 'BLS'],
#  14429: ['', 'L'],
#  13274: ['', 'MRW'],
#  14541: ['', 'SD', 'CHV', 'CVX'],
#  12140: ['', 'GR'],
#  15325: ['', 'WU', 'NVL'],
#  10698: ['', 'BBO'],
#  12503: ['', 'HR', 'NAV'],
#  11762: ['', 'ENX', 'ETN'],
#  13389: [],
#  11957: [],
#  10495: ['', 'A'],
#  10153: ['', 'AH'],
#  12095: ['', 'GRS', 'GSX'],
#  12685: [],
#  13784: [],
#  15202: ['', 'VMC'],
#  14955: ['', 'UF', 'UB', 'CQB'],
#  10217: ['', 'ABN'],
#  15528: ['', 'CV'],
#  11295: ['', 'CLU'],
#  10620: ['', 'APC', 'ACI'],
#  12263: [],
#  13098: [],
#  10073: [],
#  12597: [],
#  13303: ['', 'LT', 'NL'],
#  14656: ['', 'SUN'],
#  14912: ['', 'R'],
#  11703: ['', 'DD'],
#  11746: ['', 'ESB'],
#  14322: ['', 'S'],
#  14453: [],
#  13944: [],
#  15552: [],
#  10487: ['', 'AD'],
#  10524: ['', 'AM'],
#  10188: ['', 'AB'],
#  13805: ['', 'PFK'],
#  10460: ['', 'AME'],
#  10006: ['', 'ACF'],
#  13557: ['', 'CEI', 'NPH'],
#  14066: ['', 'PU'],
#  15376: [],
#  11770: ['', 'ET'],
#  10890: ['', 'BGH', 'UIS'],
#  10030: ['', 'ABK'],
#  11607: ['', 'DCN'],
#  13637: ['', 'OT'],
#  12466: ['', 'IC'],
#  11973: [],
#  15034: ['', 'USI'],
#  11850: ['', 'J', 'XON', 'XOM'],
#  14891: ['', 'UCL'],
#  11869: [],
#  10778: [],
#  11260: ['', 'C'],
#  10145: ['', 'ACD', 'ALD', 'HON'],
#  10161: ['', 'AMX'],
#  11447: ['', 'CH', 'CCC'],
#  15472: ['', 'WWY'],
#  19334: ['', 'WH'],
#  14277: ['', 'SLB'],
#  15659: ['', 'UK'],
#  12087: ['', 'GRX'],
#  10794: [],
#  11885: ['', 'FKM'],
#  11826: ['', 'EJN'],
#  10604: ['', 'AFI', 'ARC'],
#  10233: ['', 'ABP', 'ABC'],
#  10372: ['', 'AST'],
#  13610: ['', 'OLM', 'OLN'],
#  11375: ['', 'COG'],
#  10874: ['', 'BC'],
#  12618: [],
#  14963: [],
#  15253: ['', 'WIC'],
#  14760: ['', 'TG'],
#  12052: ['', 'GD'],
#  14701: ['', 'TEL'],
#  14007: [],
#  12036: ['', 'GMT', 'GATX'],
#  15683: [],
#  18227: [],
#  13450: ['', 'NRB'],
#  10022: [''],
#  15720: ['', 'SCE', 'EIX'],
#  10567: [],
#  12132: ['', 'GLN'],
#  12669: ['', 'KYR'],
#  12589: [],
#  11818: [],
#  15763: ['', 'AMF'],
#  15229: ['', 'MUY', 'WMC'],
#  15499: ['', 'YB'],
#  12490: ['', 'IBM'],
#  12386: ['', 'H'],
#  15413: [],
#  10364: ['', 'AR'],
#  12415: [],
#  15800: [],
#  10639: [],
#  11981: ['', 'FT'],
#  14883: ['', 'BP', 'UCC'],
#  12925: [],
#  15966: ['', 'SOM', 'MOB'],
#  16002: [],
#  13290: ['', 'MUN', 'PWA', 'WEAR'],
#  11658: ['', 'CFF', 'DEL'],
#  11121: [],
#  16037: [],
#  13311: ['', 'BI', 'NAB'],
#  16029: ['', 'DN'],
#  15069: ['', 'X', 'MRO'],
#  16053: ['', 'INR'],
#  13928: ['', 'P', 'COP'],
#  10321: ['', 'AMO'],
#  14824: ['', 'UTX', 'TU'],
#  11105: ['', 'CRT'],
#  14584: [],
#  16221: [],
#  15245: [],
#  10727: ['', 'BYK'],
#  16432: ['', 'GT'],
#  15667: ['', 'HPT', 'AHP', 'WYE'],
#  15878: [],
#  16088: ['', 'WSW'],
#  12458: ['', 'IAD', 'RT', 'RYI'],
#  16141: ['', 'AMZ'],
#  14664: ['', 'SUS'],
#  16280: ['', 'KW'],
#  16301: [],
#  16491: [],
#  15827: [],
#  16168: [],
#  15288: [],
#  12044: ['', 'GCR', 'CUC', 'CBO'],
#  11359: [''],
#  16205: ['', 'TV'],
#  10700: [],
#  16707: ['', 'JM', 'MAN'],
#  16627: [],
#  14082: ['', 'PY'],
#  15261: [],
#  16651: ['', 'BY', 'BCW'],
#  16758: ['', 'CEH', 'CH'],
#  16723: ['', 'CNR'],
#  12802: ['', 'LR'],
#  16598: ['', 'GK'],
#  11439: ['', 'CSC'],
#  11340: ['', 'CG'],
#  10663: [],
#  15886: [],
#  16571: ['', 'BN'],
#  11463: ['', 'CMR'],
#  11543: ['', 'CUD'],
#  15747: ['', 'IK'],
#  16918: [],
#  15819: ['', 'CI'],
#  13936: ['', 'PVH'],
#  16862: ['', 'NAU'],
#  16109: ['', 'GF'],
#  15165: ['', 'VC'],
#  25822: [],
#  11471: ['', 'CLL'],
#  16838: [],
#  16045: [],
#  19801: [],
#  12108: ['', 'GOU'],
#  14357: ['', 'SUO'],
#  21573: ['', 'IP'],
#  17013: ['', 'SM'],
#  16985: ['', 'IKN'],
#  17451: ['', 'LKB'],
#  17494: [],
#  17435: ['', 'EVY'],
#  17523: ['', 'SPA'],
#  17654: ['', 'RKS'],
#  14859: ['', 'TF'],
#  17646: ['', 'RVB'],
#  12511: ['', 'IGL', 'IMA', 'MKG'],
#  17718: ['', 'BLD'],
#  17566: ['', 'AS'],
#  17814: ['', 'SSH'],
#  11324: [],
#  17961: ['', 'BGG'],
#  18171: ['', 'SE'],
#  10938: ['', 'ABY'],
#  16547: [],
#  18147: ['', 'LOF', 'TNV', 'ANV'],
#  17603: [''],
#  11113: ['', 'CGI'],
#  18075: ['', 'SCW', 'AP'],
#  18008: [],
#  18032: ['', 'SPP'],
#  17929: ['', 'UGI'],
#  17742: ['', 'HH'],
#  17056: ['', 'HLN'],
#  18278: ['', 'ISS'],
#  18112: ['', 'FWC', 'FWLT'],
#  17726: ['', 'CCK'],
#  17064: [''],
#  14592: ['', 'STY'],
#  15974: ['', 'ABG'],
#  17822: ['', 'RDL', 'RTR', 'SYB'],
#  18016: ['', 'HPC'],
#  18331: ['', 'BF'],
#  16993: [],
#  17144: ['', 'GIS'],
#  18534: [],
#  18569: ['', 'FIR'],
#  17830: ['', 'UA', 'UTX', 'RTX'],
#  18374: ['', 'MHW', 'HON'],
#  14250: ['', 'SJO'],
#  18542: ['', 'CTR', 'CAT'],
#  18446: ['', 'CKL'],
#  18438: ['', 'SCX'],
#  18358: ['', 'BVA'],
#  19529: [],
#  16424: ['', 'GS', 'G'],
#  18120: [],
#  17590: ['', 'BOR'],
#  18606: ['', 'AV'],
#  18518: [],
#  18462: ['', 'HVG'],
#  18382: ['', 'MTC', 'PHA'],
#  17427: [],
#  18673: ['', 'MLR'],
#  18681: ['', 'TRW'],
#  13047: ['', 'OHO', 'MRO'],
#  10452: [],
#  18163: ['', 'PG'],
#  12001: ['', 'GRR'],
#  18841: ['', 'BK'],
#  14306: ['', 'SVE', 'VIST', 'VS', 'FQE'],
#  14189: ['', 'RS'],
#  18286: ['', 'RAY'],
#  18884: ['', 'MF'],
#  18825: ['', 'ACN'],
#  18817: ['', 'AG'],
#  18999: ['', 'CSP'],
#  18067: ['', 'ZE'],
#  18585: ['', 'HPG'],
#  16926: ['', 'CMIL'],
#  11500: ['', 'COT'],
#  19027: ['', 'CZ'],
#  17187: [],
#  17363: [],
#  18219: [],
#  11092: ['', 'CDP'],
#  12570: ['', 'IT', 'IIN', 'ITT'],
#  10866: ['', 'BWS', 'BG', 'CAL'],
#  13143: ['', 'MGM', 'GRH'],
#  18729: ['', 'CL'],
#  17312: ['', 'CLO'],
#  15712: ['', 'CK'],
#  17689: ['', 'AWC'],
#  18980: ['', 'AIN', 'AM'],
#  15157: ['', 'VRT'],
#  19115: [],
#  15050: ['', 'CJ'],
#  16686: ['', 'MLL'],
#  11287: ['', 'AP', 'CDL', 'CITA'],
#  11308: ['', 'KO'],
#  19473: [],
#  10268: ['', 'ACA', 'ACON'],
#  14728: ['', 'TCC'],
#  18198: ['', 'SW'],
#  18921: ['', 'RLM'],
#  17734: ['', 'GLZ'],
#  19131: ['', 'USG'],
#  19166: ['', 'FMC'],
#  15739: [],
#  19238: ['', 'WHX'],
#  19211: ['', 'LIL'],
#  17806: ['', 'PD'],
#  16272: ['', 'HKM'],
#  17179: [],
#  18403: ['', 'JCP'],
#  17339: ['', 'DUP'],
#  12896: ['', 'LL'],
#  19270: ['', 'BGS'],
#  16512: ['', 'MAF'],
#  14832: [''],
#  19262: [],
#  19289: ['', 'MCC'],
#  13282: [],
#  19203: ['', 'D'],
#  19254: ['', 'DI'],
#  24512: ['', 'GA'],
#  14437: ['', 'SYE'],
#  18024: [],
#  18091: ['', 'CW'],
#  13565: ['', 'CSU', 'NTS'],
#  18796: ['', 'SNL'],
#  13792: ['', 'PA', 'PC'],
#  21215: [''],
#  10516: ['', 'ADM'],
#  19342: [],
#  19369: [],
#  19350: ['', 'DE'],
#  16360: ['', 'PSY'],
#  11674: ['', 'DTE'],
#  17136: ['', 'EMI'],
#  19035: ['', 'HMW'],
#  19393: ['', 'BMY'],
#  16678: ['', 'KR'],
#  19430: ['', 'RXM'],
#  19406: ['', 'REX', 'D'],
#  18788: [],
#  16950: [],
#  17486: [''],
#  16731: ['', 'LPT'],
#  18761: ['', 'LEM', 'SBF'],
#  14680: [],
#  19537: ['', 'NC', 'NCR'],
#  17347: ['', 'HAT', 'HCA', 'MPI'],
#  15851: [],
#  19553: ['', 'SN', 'AN'],
#  17515: ['', 'CPC'],
#  13354: ['', 'DR', 'CUE'],
#  18948: ['', 'NV', 'NR', 'ROK'],
#  10479: ['', 'ASR'],
#  19502: ['', 'WAG', 'WBA'],
#  19625: [''],
#  17048: ['', 'WB'],
#  19561: ['', 'BA'],
#  16803: ['', 'NAC'],
#  19641: ['', 'ACO'],
#  19692: ['', 'ACK'],
#  19684: ['', 'CGH'],
#  19713: ['', 'SWX', 'ESM'],
#  19780: [],
#  19799: ['', 'UCF'],
#  18905: ['', 'PDG'],
#  19756: ['', 'LJ'],
#  19852: ['', 'SMC'],
#  19772: ['', 'KSP'],
#  19879: ['', 'FPP', 'FBD'],
#  19932: ['', 'WKU'],
#  25566: ['', 'DRS', 'RVD'],
#  20079: ['', 'SQD'],
#  18040: ['', 'UCB'],
#  20001: ['', 'PDC'],
#  19094: [],
#  19844: ['', 'RBR'],
#  17953: ['', 'BRY'],
#  20087: ['', 'UEF'],
#  19991: [],
#  19895: ['', 'MEA'],
#  20036: ['', 'CPP'],
#  11404: ['', 'ED'],
#  20108: [],
#  20204: ['', 'CR'],
#  18614: [],
#  20327: ['', 'NML'],
#  20263: ['', 'MGR'],
#  20052: ['', 'CTL'],
#  19975: ['', 'KES'],
#  17857: [],
#  20220: ['', 'BDK'],
#  20482: ['', 'ABT'],
#  20474: ['', 'SCT', 'SCM'],
#  17750: ['', 'KMB'],
#  20386: ['', 'MNC'],
#  20335: ['', 'PSC'],
#  20570: ['', 'NG'],
#  20060: [''],
#  13151: [''],
#  20538: ['', 'TWN', 'WHL'],
#  20466: [],
#  20503: ['', 'MUB'],
#  10436: ['', 'ZA'],
#  17902: ['', 'POR'],
#  20642: [],
#  17697: [],
#  20626: ['', 'DOW'],
#  20255: ['', 'GWD'],
#  86239: ['', 'CF', 'CFIP'],
#  13012: ['', 'MSH', 'MHT'],
#  20511: ['', 'RMC'],
#  20562: ['', 'ML'],
#  20722: [],
#  20634: [],
#  20685: [],
#  20888: ['', 'YSD'],
#  20765: ['', 'GY', 'AJRD'],
#  20810: [],
#  17240: ['', 'ARH'],
#  20394: ['', 'OM'],
#  20909: ['', 'XL', 'XLO'],
#  20933: ['', 'FGT'],
#  20802: ['', 'SDS'],
#  20650: [],
#  19860: ['', 'ADS'],
#  20837: ['', 'RNR'],
#  20941: [],
#  20343: ['', 'ROP'],
#  20853: ['', 'CWE', 'UCM'],
#  18972: [],
#  15843: ['', 'ABA'],
#  15544: ['', 'MS'],
#  10989: ['', 'CFG', 'CPC', 'BFO'],
#  20968: ['', 'UMM'],
#  17128: ['', 'ZB'],
#  19385: ['', 'SH'],
#  20167: ['', 'FO'],
#  21004: ['', 'GEN', 'GTE'],
#  20992: ['', 'CTN'],
#  11033: ['', 'CAH'],
#  21119: ['', 'CHB', 'RCB'],
#  19916: ['', 'DCS', 'VO'],
#  21135: ['', 'FOE'],
#  21143: ['', 'ARV'],
#  21186: ['', 'WP', 'W', 'MWV', 'WRK'],
#  15798: ['', 'FAW'],
#  19887: ['', 'HLY', 'HLYS'],
#  18454: [''],
#  14904: ['', 'UP'],
#  20773: ['', 'PCK'],
#  21258: ['', 'COS'],
#  20546: ['', 'ANL'],
#  19019: ['', 'NS'],
#  20829: ['', 'RL'],
#  16555: ['', 'UVV'],
#  20116: ['', 'GPE'],
#  21362: [],
#  21354: ['', 'NOP'],
#  21100: [],
#  21426: [''],
#  21178: ['', 'LK', 'LMT'],
#  21389: ['', 'PFG'],
#  21450: ['', 'SOH', 'SRD'],
#  14445: [],
#  21338: ['', 'FMO'],
#  21397: ['', 'PLY', 'UPC', 'CHA'],
#  21522: ['', 'FTR'],
#  21549: ['', 'VIS', 'AVC'],
#  21557: ['', 'JOY'],
#  17267: ['', 'PET'],
#  21493: ['', 'UAM'],
#  21565: [],
#  12562: ['', 'ILS'],
#  21530: ['', 'JL'],
#  21581: [],
#  21610: ['', 'BLL'],
#  11391: ['', 'CDR'],
#  21637: [],
#  12888: ['', 'LCE'],
#  21653: ['', 'HAY'],
#  21688: [],
#  21629: ['', 'BFC'],
#  21696: ['', 'WLJ'],
#  21266: ['', 'MCK'],
#  21290: ['', 'NOR', 'MNP', 'MTI', 'TKC', 'CDD'],
#  20693: ['', 'SSC'],
#  20618: ['', 'CRS'],
#  21768: ['', 'GO'],
#  20677: ['', 'BUR'],
#  21151: ['', 'CUN', 'CNEO'],
#  21813: ['', 'RHE'],
#  21848: [],
#  21733: ['', 'BCX'],
#  14920: ['', 'PB', 'UBC', 'GBE'],
#  12730: ['', 'ND', 'KRA'],
#  21952: [],
#  21979: ['', 'CBE'],
#  17291: ['', 'SA'],
#  19596: ['', 'UAL', 'AEG'],
#  12706: ['', 'KN'],
#  22023: ['', 'MMO', 'GWO'],
#  21872: ['', 'EGP', 'EPI'],
#  13856: ['', 'PEP'],
#  22103: ['', 'EMR'],
#  21936: ['', 'PFE'],
#  20124: ['', 'HFC', 'HI'],
#  21901: ['', 'RMB'],
#  22111: ['', 'JNJ'],
#  22090: ['', 'ESN'],
#  22234: ['', 'PSM'],
#  22170: ['', 'KOP'],
#  22162: ['', 'WYO', 'FHC', 'FHRT'],
#  22154: ['', 'AGS'],
#  22306: ['', 'RA'],
#  22293: ['', 'GLW'],
#  21725: [],
#  22322: ['', 'BHW'],
#  22242: ['', 'ERP'],
#  21012: [],
#  22373: ['', 'LUC'],
#  22533: ['', 'CRR'],
#  22592: ['', 'MMM'],
#  22509: ['', 'PPG'],
#  25259: [],
#  22680: ['', 'CMZ', 'MZ'],
#  22699: ['', 'DAY'],
#  22656: [],
#  22752: ['', 'MRK'],
#  22808: ['', 'EWB'],
#  22488: ['', 'ADL'],
#  22672: [],
#  22074: ['', 'ASU', 'VON'],
#  22664: ['', 'UNR', 'UNRI', 'ROHN'],
#  22971: ['', 'DEV'],
#  23173: [],
#  19721: ['', 'G', 'DL', 'VVI'],
#  18649: ['', 'PCO', 'PZS', 'PZB', 'BCO'],
#  23018: ['', 'MAG'],
#  22701: ['', 'EVR'],
#  11156: ['', 'CO'],
#  23245: ['', 'ENW'],
#  22787: ['', 'PUL'],
#  21274: ['', 'GQ'],
#  22349: ['', 'EPO'],
#  22082: ['', 'PEL'],
#  23333: ['', 'UYT'],
#  23341: ['', 'ACY'],
#  22277: ['', 'AYL'],
#  23384: ['', 'JAE', 'JAEG'],
#  22429: ['', 'WD'],
#  23368: [],
#  22779: ['', 'MOT', 'MSI'],
#  22824: ['', 'SRU'],
#  22007: ['', 'GDC'],
#  22146: [],
#  12861: [],
#  23480: ['', 'HKR'],
#  23325: ['', 'SRT'],
#  23579: ['', 'TXT'],
#  19705: [],
#  10225: ['', 'AT', 'AMB', 'FO', 'BEAM'],
#  12167: ['', 'GUX'],
#  23624: ['', 'ROF'],
#  23704: [],
#  21020: ['', 'AMR', 'AAL'],
#  23755: ['', 'HRF'],
#  23771: [''],
#  22568: ['', 'GNB', 'GLD'],
#  23819: ['', 'HAL'],
#  22365: ['', 'HEW'],
#  22867: ['', 'DSO'],
#  23472: ['', 'RON', 'RONC'],
#  23640: ['', 'WNS', 'BAT'],
#  23798: [],
#  14496: ['', 'SX'],
#  23595: ['', 'CPY'],
#  17881: ['', 'MTI'],
#  23990: ['', 'ROH'],
#  23747: [],
#  23886: ['', 'RBI', 'MGW', 'RDT'],
#  23982: ['', 'GAR'],
#  23974: [],
#  20140: ['', 'GLI'],
#  23421: ['', 'STN'],
#  15237: ['', 'WW'],
#  24037: ['', 'SMB'],
#  23202: ['', 'VCR'],
#  22744: [''],
#  23253: ['', 'GRL'],
#  23915: ['', 'GXP', 'GP'],
#  24336: ['', 'SCO'],
#  23149: ['', 'UDG'],
#  24408: ['', 'APS'],
#  23552: ['', 'FJQ', 'FJC'],
#  17224: ['', 'ALL'],
#  53023: ['', 'MCS', 'MERR'],
#  24459: ['', 'PBI'],
#  24213: ['', 'MCR'],
#  24280: ['', 'CAY'],
#  21485: ['', 'NWA'],
#  20159: [],
#  22840: ['', 'CFD', 'SLE', 'HSH'],
#  24539: ['', 'OAT'],
#  22736: [''],
#  22453: [''],
#  24619: ['', 'MLT', 'ET'],
#  24272: ['', 'ASH'],
#  24635: ['', 'KLU'],
#  23966: [],
#  24571: ['', 'CS'],
#  24678: ['', 'WLA'],
#  24643: ['', 'AA', 'ARNC', 'HWM'],
#  24651: ['', 'SRY'],
#  12626: ['', 'JWT', 'JWL'],
#  23165: [''],
#  24694: ['', 'SGM'],
#  24387: ['', 'SHL'],
#  24686: ['', 'KST'],
#  16344: ['', 'TMC'],
#  24715: ['', 'DIA', 'MXS'],
#  24766: ['', 'NOC'],
#  22795: ['', 'BPD', 'SOL'],
#  24811: ['', 'OCF', 'OWC'],
#  24731: ['', 'LIO'],
#  21071: ['', 'USP'],
#  23077: ['', 'HNZ'],
#  24600: ['', 'CCX'],
#  23544: ['', 'AWK'],
#  21207: ['', 'NEM'],
#  22621: ['', 'REP'],
#  24846: ['', 'AOC'],
#  15915: ['', 'DXC', 'PDI', 'PNDQ', 'CSCS'],
#  24774: [''],
#  24854: ['', 'BAW'],
#  20984: ['', 'PN'],
#  24862: ['', 'TUW', 'WGE'],
#  24897: ['', 'FEN'],
#  24942: ['', 'RTN'],
#  24598: ['', 'SKO'],
#  24918: ['', 'FNL', 'FNLI'],
#  15579: ['', 'TXN'],
#  24993: ['', 'JEF'],
#  22816: ['', 'HFI'],
#  25064: ['', 'CBO'],
#  23958: [],
#  15835: ['', 'CD'],
#  24889: ['', 'APO'],
#  25056: ['', 'LSG', 'ENS'],
#  25013: ['', 'SRG', 'SGP'],
#  19297: ['', 'CPS'],
#  15691: [],
#  22605: ['', 'NLV', 'NVF'],
#  22330: ['', 'NSU'],
#  23106: ['', 'CNB', 'CKB'],
#  25048: ['', 'FLT'],
#  23376: ['', 'CRC'],
#  11017: ['', 'CMN'],
#  24758: ['', 'SCH'],
#  25224: [''],
#  25275: [],
#  25216: ['', 'STF'],
#  25005: ['', 'GRA'],
#  22875: [''],
#  25312: ['', 'RHR'],
#  25355: [],
#  24061: ['', 'UGC'],
#  21434: ['', 'BIW', 'COG'],
#  25451: [],
#  24627: ['', 'MIS'],
#  25240: [],
#  25507: ['', 'LTV'],
#  25582: ['', 'HI', 'HRS', 'LHX'],
#  24221: ['', 'BGE', 'CEG'],
#  25128: ['', 'SDG'],
#  25662: ['', 'ANK', 'AXO'],
#  25419: ['', 'WHR'],
#  25531: ['', 'MIC', 'MCP'],
#  25646: ['', 'FOR', 'MCK'],
#  25697: ['', 'BEC'],
#  25638: ['', 'AQP'],
#  21303: ['', 'RCC'],
#  25160: ['', 'GPP', 'GNN'],
#  25398: ['', 'HEC'],
#  25654: ['', 'SGS'],
#  25785: ['', 'F'],
#  19190: ['', 'CMY'],
#  25718: ['', 'KFM', 'RYR'],
#  25371: ['', 'FBO'],
#  25742: [''],
#  25793: ['', 'HCM'],
#  23800: ['', 'GSK'],
#  22760: ['', 'MOH'],
#  24520: [''],
#  20845: ['', 'WOD'],
#  12837: ['', 'LM', 'LGT'],
#  25777: [],
#  25486: ['', 'NSB'],
#  14218: ['', 'RJR'],
#  25865: ['', 'BWG'],
#  25814: ['', 'FNT'],
#  25857: [],
#  25849: ['', 'RNI'],
#  25574: ['', 'TRA'],
#  58843: ['', 'AHC', 'EMH'],
#  25910: ['', 'GEB'],
#  25806: ['', 'RGP'],
#  25902: ['', 'GSI'],
#  25953: ['', 'DOV'],
#  13901: ['', 'MO'],
#  26016: ['', 'SHK'],
#  25187: [''],
#  25435: [],
#  26147: [''],
#  26155: ['', 'ITE'],
#  26024: ['', 'UTD'],
#  19617: ['', 'TWA'],
#  12941: ['', 'MQ'],
#  26235: ['', 'MRY'],
#  26227: ['', 'AAE'],
#  26251: ['', 'GCC'],
#  26243: ['', 'FTE'],
#  26307: ['', 'REE'],
#  26198: ['', 'SLR'],
#  26294: ['', 'LIT'],
#  26315: [],
#  26366: ['', 'USH', 'USM'],
#  26171: ['', 'MXR'],
#  25750: ['', 'CEA'],
#  24555: ['', 'AGM'],
#  25347: ['', 'FPC'],
#  26390: ['', 'SKL', 'SKB'],
#  26438: ['', 'PRD'],
#  23050: ['', 'RVS'],
#  26331: ['', 'ADP'],
#  26454: ['', 'SNS'],
#  26278: ['', 'HMD'],
#  26411: ['', 'GLD'],
#  25996: [],
#  26518: ['', 'BOL'],
#  26200: ['', 'UBX'],
#  26382: ['', 'FLR', 'MEE'],
#  26534: ['', 'MDE'],
#  25304: ['', 'HSC'],
#  25320: ['', 'CPB'],
#  24926: ['', 'HML'],
#  26577: ['', 'RCI'],
#  17160: ['', 'YG', 'HRD'],
#  26446: ['', 'SPK'],
#  26489: ['', 'LSI'],
#  19764: ['', 'PFB', 'ABW', 'AMDA'],
#  22269: ['', 'WSX', 'WAL'],
#  13688: ['', 'PCG'],
#  21514: ['', 'SGA', 'NRG', 'SNT'],
#  25427: ['', 'OXP'],
#  26374: ['', 'CAR'],
#  26681: ['', 'UPJ'],
#  26665: ['', 'THI'],
#  21127: ['', 'BLI', 'AX'],
#  26796: ['', 'UOP'],
#  26622: ['', 'CHM'],
#  26753: ['', 'NSD'],
#  24969: ['', 'WWP', 'AVA'],
#  26868: ['', 'KEN'],
#  26956: ['', 'WLT'],
#  26761: ['', 'NPM'],
#  23456: ['', 'DCO'],
#  27043: ['', 'VAR'],
#  26673: ['', 'APX'],
#  19828: ['', 'DWG', 'TRY', 'WEN'],
#  14154: ['', 'RDG', 'RDGC', 'RDGCA', 'RDGE'],
#  26980: ['', 'RYC'],
#  27094: ['', 'CRI'],
#  27051: ['', 'AMP'],
#  26884: ['', 'RBD'],
#  27158: ['', 'CSY'],
#  26921: ['', 'UMT', 'UMC', 'UD'],
#  27190: ['', 'AHS'],
#  17005: ['', 'MES', 'CVS'],
#  27131: ['', 'MKE'],
#  27019: [''],
#  27238: ['', 'VEN'],
#  21231: ['', 'WGL'],
#  27123: ['', 'MRQ'],
#  26403: ['', 'DIS'],
#  68523: ['', 'APY', 'APEC', 'LRC', 'CFS'],
#  27166: ['', 'GBA'],
#  27406: ['', 'RII'],
#  27430: ['', 'CTB'],
#  27262: ['', 'WRN'],
#  27473: ['', 'SMF'],
#  27326: ['', 'TOR'],
#  27422: ['', 'CLF'],
#  27545: ['', 'IGC'],
#  27369: ['', 'INT', 'IRC'],
#  27596: ['', 'ENG', 'PB', 'PSB', 'SB'],
#  10014: ['', 'AJ'],
#  27502: ['', 'ARO'],
#  23069: ['', 'DES'],
#  22920: ['', 'SUC', 'ITC'],
#  26788: ['', 'TXG'],
#  27713: ['', 'PKN', 'PEB', 'ABI'],
#  24264: ['', 'AL'],
#  25988: ['', 'REV'],
#  25195: ['', 'MQC'],
#  27318: ['', 'NSW'],
#  27676: ['', 'SPG'],
#  27721: ['', 'BDC'],
#  26729: ['', 'MAC', 'MD'],
#  27609: ['', 'HBB', 'HVU'],
#  12343: ['', 'HW'],
#  27772: ['', 'TPT'],
#  27828: ['', 'HWP', 'HPQ'],
#  21055: ['', 'GCO'],
#  20976: ['', 'EAL'],
#  27887: ['', 'BAX'],
#  27705: ['', 'IRF'],
#  18243: ['', 'CHC'],
#  27799: ['', 'AEM'],
#  27780: ['', 'SDP', 'ST'],
#  27668: ['', 'PPM'],
#  27270: ['', 'ARM'],
#  27182: ['', 'TRN', 'TSIE', 'TREL'],
#  27860: ['', 'FOX'],
#  27078: ['', 'AIR', 'KEL'],
#  27983: ['', 'XRX'],
#  27967: ['', 'FRC'],
#  28003: ['', 'LSO'],
#  28134: ['', 'BKO'],
#  28054: ['', 'HZ'],
#  28142: ['', 'CCP'],
#  28169: ['', 'FCI'],
#  27641: ['', 'BAI'],
#  28222: ['', 'APD'],
#  26526: ['', 'FMF'],
#  28302: ['', 'UL'],
#  27203: ['', 'DSP'],
#  28337: ['', 'LFE'],
#  28185: ['', 'FR'],
#  28257: ['', 'SWL'],
#  28417: ['', 'MIL'],
#  20706: ['', 'AKD'],
#  27879: ['', 'HC'],
#  28193: ['', 'NSC'],
#  28396: ['', 'BLG'],
#  28011: ['', 'PKG'],
#  28249: ['', 'HLF'],
#  17232: ['', 'CEG', 'AGG'],
#  28441: ['', 'FIS'],
#  30779: ['GIN', 'CAX'],
#  35270: ['PPR'],
#  30592: ['CLY'],
#  33988: ['GMF', 'MAB', 'HRI'],
#  37575: ['UAP'],
#  23683: ['', 'FAL', 'FALB'],
#  31421: ['DUR'],
#  32619: ['HMF'],
#  34809: ['NOV', '', 'NOVO'],
#  36011: ['RRO'],
#  34040: ['MSE', 'VAT'],
#  33072: ['IMP', 'ICI'],
#  32256: ['GDS'],
#  37321: ['TSL'],
#  27895: ['', 'CAL'],
#  30947: ['COU'],
#  31181: ['DSN'],
#  33363: ['KDE'],
#  35051: ['PPL', 'PLL'],
#  35289: ['PEF'],
#  37778: ['VLV', 'VCA'],
#  36468: ['SHW'],
#  29890: ['BPT', 'BP', 'BPA'],
#  37102: ['SYN'],
#  34817: ['NUE'],
#  36409: ['SCA'],
#  35887: ['RX'],
#  32504: ['GUL'],
#  35158: ['CHY', 'PAX', '', 'PAXL'],
#  31915: ['FP'],
#  34411: ['NRU', 'NRM'],
#  29700: ['BRC'],
#  21346: ['', 'FFS'],
#  29989: ['TC', 'BKR'],
#  34569: ['NVD'],
#  30736: ['CEM'],
#  37698: ['USU'],
#  31368: ['DA'],
#  32563: ['HRC', 'HPH'],
#  33582: ['LKK'],
#  34403: ['NAH'],
#  32272: ['GLB'],
#  35991: ['ROG'],
#  38199: ['WNW'],
#  32694: ['HLI'],
#  34622: ['NJZ'],
#  31616: ['ELS'],
#  36388: ['SBG'],
#  36775: ['SPD'],
#  31085: ['CUG'],
#  31405: ['DLP'],
#  35342: ['PIA'],
#  34083: ['MEN'],
#  33427: ['KPT'],
#  36425: ['SMI'],
#  35844: ['REM'],
#  37591: ['AMK'],
#  33638: ['LMC'],
#  36628: ['SON'],
#  34366: ['MYO'],
#  31480: ['EML'],
#  33769: ['LSP'],
#  33283: ['KI'],
#  36978: ['SCC', 'STO'],
#  29196: ['AKG', 'ALG', 'NAE'],
#  34825: ['OAK', 'OEN'],
#  34518: ['NCI'],
#  34147: ['MAI'],
#  31595: ['EAC'],
#  32766: ['HOE'],
#  29137: ['ACH', 'AFX'],
#  38375: ['WIT'],
#  31245: ['DIL'],
#  38332: ['ELV'],
#  31464: ['DCA', '', 'DYA'],
#  29022: ['AFT'],
#  29559: ['BIR'],
#  29188: ['ARX'],
#  29815: ['BRZ'],
#  36847: ['STI'],
#  37823: ['VLX'],
#  32379: ['GLK'],
#  35756: ['RHP', 'RATH'],
#  34120: ['MCH'],
#  28871: ['ACC'],
#  34155: ['MIK'],
#  38447: ['IHS', 'EYE'],
#  31333: ['DOR'],
#  38359: ['RAD'],
#  35449: ['POD'],
#  35430: ['PNU'],
#  33240: ['IHV', 'III', 'IRV'],
#  29911: ['BWN'],
#  33849: ['LGL'],
#  32993: ['HY'],
#  38578: ['TNB'],
#  30533: ['CRO'],
#  26876: ['', 'NOA'],
#  35369: ['TIC', 'PTV'],
#  37217: ['TO', 'LDR'],
#  33267: ['JET'],
#  29401: ['AVS'],
#  36863: ['LOC', 'SAR'],
#  33785: ['LOR'],
#  31632: ['ECA'],
#  37006: ['SRN'],
#  38420: ['CNK', 'CNW', 'CK', 'CEM', '', 'CHMT'],
#  33670: ['HLP', 'LED'],
#  29903: ['BKI'],
#  29145: ['ANT', 'KTO'],
#  34104: ['MT'],
#  38543: ['EA'],
#  28628: ['MSK', 'AP'],
#  28433: ['', 'PNC', 'KCG', 'KCC'],
#  37807: ['VAL'],
#  38041: ['EQU', 'WFI'],
#  31261: ['DIV'],
#  37268: ['TP'],
#  31923: ['FSS'],
#  28820: ['AEN', 'AAMN'],
#  38180: ['WLB'],
#  35641: ['PYL'],
#  31077: ['CUB'],
#  36994: ['SUW'],
#  36759: ['SDR', '', 'STDG'],
#  35465: ['PLM'],
#  35916: ['CRG', 'RIC', '', 'RIHL', 'RHT'],
#  37786: ['VIC', 'VLN'],
#  32037: ['GLP', 'GFB'],
#  34374: ['MTR'],
#  37305: ['TEX'],
#  36791: ['STH'],
#  28310: ['', 'UN'],
#  30576: ['CCC'],
#  34868: ['OHS'],
#  29380: ['ART'],
#  32408: ['GRH'],
#  28724: ['AER'],
#  33400: ['THE', 'TOC', 'KNG', 'KNGO'],
#  34032: ['MAS'],
#  29858: ['BLO'],
#  28468: ['', 'GVL'],
#  30998: ['CRE', ''],
#  26825: ['', 'K'],
#  ...}

# %%
len(patent_permno_ticker)
# Out:
# 8547

# %%
# 逐个提取permno对应的在df中的数据，并分别建立新文件保存
for permno in patent_original_data_permno:
    df_temp = df[df['PERMNO'] == permno]
    df_temp.to_csv(f'/home/bld/bld_data/pengliu/Stock Data/CRSP_Split_Data/CRSP_{permno}.csv', index=False)
